# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
leokas = ['ucr_leoka_monthly_1960_2020_dta/leoka_monthly_2017.dta',
          'ucr_leoka_monthly_1960_2020_dta/leoka_monthly_2016.dta',
          'ucr_leoka_monthly_1960_2020_dta/leoka_monthly_2015.dta',
          'ucr_leoka_monthly_1960_2020_dta/leoka_monthly_2014.dta',
          'ucr_leoka_monthly_1960_2020_dta/leoka_monthly_2013.dta']
leoka_17, leoka_16, leoka_15, leoka_14, leoka_13 = pd.read_stata(leokas[0]), pd.read_stata(leokas[1]), pd.read_stata(leokas[2]), pd.read_stata(leokas[3]), pd.read_stata(leokas[4])

dfs = [leoka_13, leoka_14, leoka_15, leoka_16, leoka_17]
dfs = [i.iloc[:,:-198] for i in dfs]

for j in dfs:
    print(j.shape)
# Out:
# (266424, 58)
# (267972, 58)
# (270288, 58)
# (271740, 58)
# (273408, 58)

# %%
df = pd.concat(dfs, ignore_index=True)
df.shape
# Out:
# (1349832, 58)

# %%
month_map = {'january': 1, 'february': 2, 'march': 3, 'april': 4, 'may': 5, 'june': 6, 'july': 7, 'august': 8, 'september': 9, 'october': 10, 'november': 11, 'december': 12}
df['month_code'] = df['month'].map(month_map) + (df['year'] - 2013)*12

# %%
#filter into assaults ever
df['total_assaults'] = df['assaults_no_injury_total'] + df['assaults_with_injury_total']
officer_assaulted = (df['total_assaults'] > 0)
ori_to_keep = df.loc[officer_assaulted, 'ori'].unique()
df = df[df['ori'].isin(ori_to_keep)]
df.shape #shape is 1286712 x 60 (about half the municipalities were retained)
# Out:
# (532356, 60)

# %%
#add sizes for all municipalities according to first observation per municipality
df['first_pop'] = df.groupby('ori')['population'].transform('first')
df['first_employment'] = df.groupby('ori')['total_employees_officers'].transform('first')

# %%
#column transformations

#drop 0 pop rows to avoid division by 0
df = df.loc[df['first_pop'] > 0]

#force size mechanism construction
median_condition = df['first_employment'] > df['first_employment'].median()
trueval, falseval = 1, 0
df['employment_median_indicator'] = np.where(median_condition, trueval, falseval)

#proportion mechanism
df['employment_pop_proportion'] = df['first_employment']/df['first_pop']
prop_median_condition = df['employment_pop_proportion'] > df['employment_pop_proportion'].median()
df['employment_pop_prop_indicator'] = np.where(prop_median_condition, trueval, falseval)

# %%
df = df.sort_values(by=['ori', 'month_code'])

# %%
for i in range(7):
    df[f'PreviousTreatment_{i}'] = df.groupby('ori')['officers_killed_total'].shift(i)
    df[f'post_{i}'] = df[f'PreviousTreatment_{i}'] > 0

    #don't do the idxmin thing, shouldn't matter since things are NaN where edge case shifts; drop the NaNs by removing the PreviousTreament_i columns

    df[f'post_{i}'] = df[f'post_{i}'].astype(int)
    df = df.drop(columns=[f'PreviousTreatment_{i}'])

# %%
#make three pre-treatment month indicators
for i in range(1, 4, 1):
    df[f'FutureTreatment_{i}'] = df.groupby('ori')['officers_killed_total'].shift(-1*i)
    df[f'pre_{i}'] = df[f'FutureTreatment_{i}'] > 0
    df[f'pre_{i}'] = df[f'pre_{i}'].astype(int)
    df = df.drop(columns=[f'FutureTreatment_{i}'])

# %%
df['assault_indicator'] = (df['total_assaults'] > 0).astype(int)

# %%
ucrs = ['ucr_arrests_monthly_index_1974_2018_dta/ucr_arrests_monthly_index_crimes_age_2017.dta',
        'ucr_arrests_monthly_index_1974_2018_dta/ucr_arrests_monthly_index_crimes_age_2016.dta',
        'ucr_arrests_monthly_index_1974_2018_dta/ucr_arrests_monthly_index_crimes_age_2015.dta',
        'ucr_arrests_monthly_index_1974_2018_dta/ucr_arrests_monthly_index_crimes_age_2014.dta',
        'ucr_arrests_monthly_index_1974_2018_dta/ucr_arrests_monthly_index_crimes_age_2013.dta']

ucr_17, ucr_16, ucr_15, ucr_14, ucr_13 = pd.read_stata(ucrs[0]), pd.read_stata(ucrs[1]), pd.read_stata(ucrs[2]), pd.read_stata(ucrs[3]), pd.read_stata(ucrs[4])

# %%
ucr_dfs = [ucr_13, ucr_14, ucr_15, ucr_16, ucr_17]
ucr = pd.concat(ucr_dfs, ignore_index=True)
ucr['total_arrests'] = ucr['theft_tot_arrests'] + ucr['robbery_tot_arrests'] + ucr['rape_tot_arrests'] + ucr['murder_tot_arrests'] + ucr['mtr_veh_theft_tot_arrests'] + ucr['burglary_tot_arrests'] + ucr['arson_tot_arrests'] + ucr['agg_assault_tot_arrests']
ucr['log_total_arrests'] = np.log(ucr['total_arrests'] + 1)
# Out:
# /var/folders/5h/mg9jv4jj4_zc1dsmj4zsf1vm0000gn/T/ipykernel_65305/2892541529.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ucr['total_arrests'] = ucr['theft_tot_arrests'] + ucr['robbery_tot_arrests'] + ucr['rape_tot_arrests'] + ucr['murder_tot_arrests'] + ucr['mtr_veh_theft_tot_arrests'] + ucr['burglary_tot_arrests'] + ucr['arson_tot_arrests'] + ucr['agg_assault_tot_arrests']
# /Users/srinidhi/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/5h/mg9jv4jj4_zc1dsmj4zsf1vm0000gn/T/ipykernel_65305/2892541529.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ucr['log_total_arrests'] = np.log(ucr['total_arrests'] + 1)

# %%
ucr['month_code'] = ucr['month'].map(month_map) + (ucr['year'] - 2013)*12
df = df.drop_duplicates(subset=['ori', 'month_code'])
ucr = ucr.drop_duplicates(subset=['ori', 'month_code'])
# Out:
# /var/folders/5h/mg9jv4jj4_zc1dsmj4zsf1vm0000gn/T/ipykernel_65305/2433599158.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ucr['month_code'] = ucr['month'].map(month_map) + (ucr['year'] - 2013)*12

# %%
ucr.shape
merged = pd.merge(df, ucr, on=['ori', 'month_code', 'year'], how='left')
df.shape, ucr.shape, merged.shape
# Out:
# ((465876, 76), (846711, 632), (465876, 705))

# %%
#data to run first two stage regressions
merged.to_stata('event_study.dta')

# %%
#dataset creation for stage 3
overall_conditions = [(merged['post_0'] + merged['post_1'] + merged['post_2'] + merged['post_4'] >= 1),
                      (merged['pre_1'] + merged['pre_2'] + merged['pre_3'] >= 1)]
overall_condition_values = [1, 0] #2 is default value
merged['post_overall'] = np.select(overall_conditions, overall_condition_values, default=2)

# %%
avg_data = merged.loc[merged['post_overall'] < 2]

# %%
merged.shape, avg_data.shape
# Out:
# ((465876, 706), (1467, 706))

# %%
avg_data.to_stata('DDD.dta')

# %%
for i in merged.columns:
    print(i)
# Out:
# ori
# agency_name_x
# state_x
# state_abb_x
# number_of_months_reported_x
# year
# month_x
# date
# ori9_x
# fips_state_code_x
# fips_county_code_x
# fips_state_county_code_x
# fips_place_code_x
# agency_type
# crosswalk_agency_name
# census_name
# longitude
# latitude
# address_name
# address_street_line_1
# address_street_line_2
# address_city
# address_state
# address_zip_code
# population_x
# population_group_x
# country_division_x
# msa
# report_indicator
# record_indicator
# month_indicator
# covered_by_x
# shift_data
# no_male_female_breakdown
# assault_injury_indicator
# assault_no_injury_indicator
# male_employees_officers
# female_employees_officers
# total_employees_officers
# male_employees_civilians
# female_employees_civilians
# total_employees_civilians
# male_employees_total
# female_employees_total
# total_employees_total
# officers_killed_total
# officers_killed_by_felony
# officers_killed_by_accident
# assaults_with_injury_gun
# assaults_with_injury_knife
# assaults_with_injury_oth_weap
# assaults_with_injury_unarmed
# assaults_with_injury_total
# assaults_no_injury_gun
# assaults_no_injury_knife
# assaults_no_injury_oth_weap
# assaults_no_injury_unarmed
# assaults_no_injury_total
# month_code
# total_assaults
# first_pop
# first_employment
# employment_median_indicator
# employment_pop_proportion
# employment_pop_prop_indicator
# post_0
# post_1
# post_2
# post_3
# post_4
# post_5
# post_6
# pre_1
# pre_2
# pre_3
# assault_indicator
# ori9_y
# number_of_months_reported_y
# num_months_murder
# num_months_rape
# num_months_robbery
# num_months_agg_assault
# num_months_burglary
# num_months_theft
# num_months_mtr_veh_theft
# num_months_arson
# population_y
# agency_name_y
# month_y
# state_y
# state_abb_y
# population_group_y
# country_division_y
# fips_state_code_y
# fips_county_code_y
# fips_state_county_code_y
# fips_place_code_y
# covered_by_y
# agg_assault_female_10_12
# agg_assault_female_13_14
# agg_assault_female_15
# agg_assault_female_16
# agg_assault_female_17
# agg_assault_female_18
# agg_assault_female_19
# agg_assault_female_20
# agg_assault_female_21
# agg_assault_female_22
# agg_assault_female_23
# agg_assault_female_24
# agg_assault_female_25_29
# agg_assault_female_30_34
# agg_assault_female_35_39
# agg_assault_female_40_44
# agg_assault_female_45_49
# agg_assault_female_50_54
# agg_assault_female_55_59
# agg_assault_female_60_64
# agg_assault_female_over_64
# agg_assault_female_under_10
# agg_assault_male_10_12
# agg_assault_male_13_14
# agg_assault_male_15
# agg_assault_male_16
# agg_assault_male_17
# agg_assault_male_18
# agg_assault_male_19
# agg_assault_male_20
# agg_assault_male_21
# agg_assault_male_22
# agg_assault_male_23
# agg_assault_male_24
# agg_assault_male_25_29
# agg_assault_male_30_34
# agg_assault_male_35_39
# agg_assault_male_40_44
# agg_assault_male_45_49
# agg_assault_male_50_54
# agg_assault_male_55_59
# agg_assault_male_60_64
# agg_assault_male_over_64
# agg_assault_male_under_10
# agg_assault_tot_10_12
# agg_assault_tot_13_14
# agg_assault_tot_15
# agg_assault_tot_16
# agg_assault_tot_17
# agg_assault_tot_18
# agg_assault_tot_19
# agg_assault_tot_20
# agg_assault_tot_21
# agg_assault_tot_22
# agg_assault_tot_23
# agg_assault_tot_24
# agg_assault_tot_25_29
# agg_assault_tot_30_34
# agg_assault_tot_35_39
# agg_assault_tot_40_44
# agg_assault_tot_45_49
# agg_assault_tot_50_54
# agg_assault_tot_55_59
# agg_assault_tot_60_64
# agg_assault_tot_adult
# agg_assault_tot_arrests
# agg_assault_tot_female
# agg_assault_tot_female_adult
# agg_assault_tot_female_juv
# agg_assault_tot_juv
# agg_assault_tot_male
# agg_assault_tot_male_adult
# agg_assault_tot_male_juv
# agg_assault_tot_over_64
# agg_assault_tot_under_10
# arson_female_10_12
# arson_female_13_14
# arson_female_15
# arson_female_16
# arson_female_17
# arson_female_18
# arson_female_19
# arson_female_20
# arson_female_21
# arson_female_22
# arson_female_23
# arson_female_24
# arson_female_25_29
# arson_female_30_34
# arson_female_35_39
# arson_female_40_44
# arson_female_45_49
# arson_female_50_54
# arson_female_55_59
# arson_female_60_64
# arson_female_over_64
# arson_female_under_10
# arson_male_10_12
# arson_male_13_14
# arson_male_15
# arson_male_16
# arson_male_17
# arson_male_18
# arson_male_19
# arson_male_20
# arson_male_21
# arson_male_22
# arson_male_23
# arson_male_24
# arson_male_25_29
# arson_male_30_34
# arson_male_35_39
# arson_male_40_44
# arson_male_45_49
# arson_male_50_54
# arson_male_55_59
# arson_male_60_64
# arson_male_over_64
# arson_male_under_10
# arson_tot_10_12
# arson_tot_13_14
# arson_tot_15
# arson_tot_16
# arson_tot_17
# arson_tot_18
# arson_tot_19
# arson_tot_20
# arson_tot_21
# arson_tot_22
# arson_tot_23
# arson_tot_24
# arson_tot_25_29
# arson_tot_30_34
# arson_tot_35_39
# arson_tot_40_44
# arson_tot_45_49
# arson_tot_50_54
# arson_tot_55_59
# arson_tot_60_64
# arson_tot_adult
# arson_tot_arrests
# arson_tot_female
# arson_tot_female_adult
# arson_tot_female_juv
# arson_tot_juv
# arson_tot_male
# arson_tot_male_adult
# arson_tot_male_juv
# arson_tot_over_64
# arson_tot_under_10
# burglary_female_10_12
# burglary_female_13_14
# burglary_female_15
# burglary_female_16
# burglary_female_17
# burglary_female_18
# burglary_female_19
# burglary_female_20
# burglary_female_21
# burglary_female_22
# burglary_female_23
# burglary_female_24
# burglary_female_25_29
# burglary_female_30_34
# burglary_female_35_39
# burglary_female_40_44
# burglary_female_45_49
# burglary_female_50_54
# burglary_female_55_59
# burglary_female_60_64
# burglary_female_over_64
# burglary_female_under_10
# burglary_male_10_12
# burglary_male_13_14
# burglary_male_15
# burglary_male_16
# burglary_male_17
# burglary_male_18
# burglary_male_19
# burglary_male_20
# burglary_male_21
# burglary_male_22
# burglary_male_23
# burglary_male_24
# burglary_male_25_29
# burglary_male_30_34
# burglary_male_35_39
# burglary_male_40_44
# burglary_male_45_49
# burglary_male_50_54
# burglary_male_55_59
# burglary_male_60_64
# burglary_male_over_64
# burglary_male_under_10
# burglary_tot_10_12
# burglary_tot_13_14
# burglary_tot_15
# burglary_tot_16
# burglary_tot_17
# burglary_tot_18
# burglary_tot_19
# burglary_tot_20
# burglary_tot_21
# burglary_tot_22
# burglary_tot_23
# burglary_tot_24
# burglary_tot_25_29
# burglary_tot_30_34
# burglary_tot_35_39
# burglary_tot_40_44
# burglary_tot_45_49
# burglary_tot_50_54
# burglary_tot_55_59
# burglary_tot_60_64
# burglary_tot_adult
# burglary_tot_arrests
# burglary_tot_female
# burglary_tot_female_adult
# burglary_tot_female_juv
# burglary_tot_juv
# burglary_tot_male
# burglary_tot_male_adult
# burglary_tot_male_juv
# burglary_tot_over_64
# burglary_tot_under_10
# mtr_veh_theft_female_10_12
# mtr_veh_theft_female_13_14
# mtr_veh_theft_female_15
# mtr_veh_theft_female_16
# mtr_veh_theft_female_17
# mtr_veh_theft_female_18
# mtr_veh_theft_female_19
# mtr_veh_theft_female_20
# mtr_veh_theft_female_21
# mtr_veh_theft_female_22
# mtr_veh_theft_female_23
# mtr_veh_theft_female_24
# mtr_veh_theft_female_25_29
# mtr_veh_theft_female_30_34
# mtr_veh_theft_female_35_39
# mtr_veh_theft_female_40_44
# mtr_veh_theft_female_45_49
# mtr_veh_theft_female_50_54
# mtr_veh_theft_female_55_59
# mtr_veh_theft_female_60_64
# mtr_veh_theft_female_over_64
# mtr_veh_theft_female_under_10
# mtr_veh_theft_male_10_12
# mtr_veh_theft_male_13_14
# mtr_veh_theft_male_15
# mtr_veh_theft_male_16
# mtr_veh_theft_male_17
# mtr_veh_theft_male_18
# mtr_veh_theft_male_19
# mtr_veh_theft_male_20
# mtr_veh_theft_male_21
# mtr_veh_theft_male_22
# mtr_veh_theft_male_23
# mtr_veh_theft_male_24
# mtr_veh_theft_male_25_29
# mtr_veh_theft_male_30_34
# mtr_veh_theft_male_35_39
# mtr_veh_theft_male_40_44
# mtr_veh_theft_male_45_49
# mtr_veh_theft_male_50_54
# mtr_veh_theft_male_55_59
# mtr_veh_theft_male_60_64
# mtr_veh_theft_male_over_64
# mtr_veh_theft_male_under_10
# mtr_veh_theft_tot_10_12
# mtr_veh_theft_tot_13_14
# mtr_veh_theft_tot_15
# mtr_veh_theft_tot_16
# mtr_veh_theft_tot_17
# mtr_veh_theft_tot_18
# mtr_veh_theft_tot_19
# mtr_veh_theft_tot_20
# mtr_veh_theft_tot_21
# mtr_veh_theft_tot_22
# mtr_veh_theft_tot_23
# mtr_veh_theft_tot_24
# mtr_veh_theft_tot_25_29
# mtr_veh_theft_tot_30_34
# mtr_veh_theft_tot_35_39
# mtr_veh_theft_tot_40_44
# mtr_veh_theft_tot_45_49
# mtr_veh_theft_tot_50_54
# mtr_veh_theft_tot_55_59
# mtr_veh_theft_tot_60_64
# mtr_veh_theft_tot_adult
# mtr_veh_theft_tot_arrests
# mtr_veh_theft_tot_female
# mtr_veh_theft_tot_female_adult
# mtr_veh_theft_tot_female_juv
# mtr_veh_theft_tot_juv
# mtr_veh_theft_tot_male
# mtr_veh_theft_tot_male_adult
# mtr_veh_theft_tot_male_juv
# mtr_veh_theft_tot_over_64
# mtr_veh_theft_tot_under_10
# murder_female_10_12
# murder_female_13_14
# murder_female_15
# murder_female_16
# murder_female_17
# murder_female_18
# murder_female_19
# murder_female_20
# murder_female_21
# murder_female_22
# murder_female_23
# murder_female_24
# murder_female_25_29
# murder_female_30_34
# murder_female_35_39
# murder_female_40_44
# murder_female_45_49
# murder_female_50_54
# murder_female_55_59
# murder_female_60_64
# murder_female_over_64
# murder_female_under_10
# murder_male_10_12
# murder_male_13_14
# murder_male_15
# murder_male_16
# murder_male_17
# murder_male_18
# murder_male_19
# murder_male_20
# murder_male_21
# murder_male_22
# murder_male_23
# murder_male_24
# murder_male_25_29
# murder_male_30_34
# murder_male_35_39
# murder_male_40_44
# murder_male_45_49
# murder_male_50_54
# murder_male_55_59
# murder_male_60_64
# murder_male_over_64
# murder_male_under_10
# murder_tot_10_12
# murder_tot_13_14
# murder_tot_15
# murder_tot_16
# murder_tot_17
# murder_tot_18
# murder_tot_19
# murder_tot_20
# murder_tot_21
# murder_tot_22
# murder_tot_23
# murder_tot_24
# murder_tot_25_29
# murder_tot_30_34
# murder_tot_35_39
# murder_tot_40_44
# murder_tot_45_49
# murder_tot_50_54
# murder_tot_55_59
# murder_tot_60_64
# murder_tot_adult
# murder_tot_arrests
# murder_tot_female
# murder_tot_female_adult
# murder_tot_female_juv
# murder_tot_juv
# murder_tot_male
# murder_tot_male_adult
# murder_tot_male_juv
# murder_tot_over_64
# murder_tot_under_10
# rape_female_10_12
# rape_female_13_14
# rape_female_15
# rape_female_16
# rape_female_17
# rape_female_18
# rape_female_19
# rape_female_20
# rape_female_21
# rape_female_22
# rape_female_23
# rape_female_24
# rape_female_25_29
# rape_female_30_34
# rape_female_35_39
# rape_female_40_44
# rape_female_45_49
# rape_female_50_54
# rape_female_55_59
# rape_female_60_64
# rape_female_over_64
# rape_female_under_10
# rape_male_10_12
# rape_male_13_14
# rape_male_15
# rape_male_16
# rape_male_17
# rape_male_18
# rape_male_19
# rape_male_20
# rape_male_21
# rape_male_22
# rape_male_23
# rape_male_24
# rape_male_25_29
# rape_male_30_34
# rape_male_35_39
# rape_male_40_44
# rape_male_45_49
# rape_male_50_54
# rape_male_55_59
# rape_male_60_64
# rape_male_over_64
# rape_male_under_10
# rape_tot_10_12
# rape_tot_13_14
# rape_tot_15
# rape_tot_16
# rape_tot_17
# rape_tot_18
# rape_tot_19
# rape_tot_20
# rape_tot_21
# rape_tot_22
# rape_tot_23
# rape_tot_24
# rape_tot_25_29
# rape_tot_30_34
# rape_tot_35_39
# rape_tot_40_44
# rape_tot_45_49
# rape_tot_50_54
# rape_tot_55_59
# rape_tot_60_64
# rape_tot_adult
# rape_tot_arrests
# rape_tot_female
# rape_tot_female_adult
# rape_tot_female_juv
# rape_tot_juv
# rape_tot_male
# rape_tot_male_adult
# rape_tot_male_juv
# rape_tot_over_64
# rape_tot_under_10
# robbery_female_10_12
# robbery_female_13_14
# robbery_female_15
# robbery_female_16
# robbery_female_17
# robbery_female_18
# robbery_female_19
# robbery_female_20
# robbery_female_21
# robbery_female_22
# robbery_female_23
# robbery_female_24
# robbery_female_25_29
# robbery_female_30_34
# robbery_female_35_39
# robbery_female_40_44
# robbery_female_45_49
# robbery_female_50_54
# robbery_female_55_59
# robbery_female_60_64
# robbery_female_over_64
# robbery_female_under_10
# robbery_male_10_12
# robbery_male_13_14
# robbery_male_15
# robbery_male_16
# robbery_male_17
# robbery_male_18
# robbery_male_19
# robbery_male_20
# robbery_male_21
# robbery_male_22
# robbery_male_23
# robbery_male_24
# robbery_male_25_29
# robbery_male_30_34
# robbery_male_35_39
# robbery_male_40_44
# robbery_male_45_49
# robbery_male_50_54
# robbery_male_55_59
# robbery_male_60_64
# robbery_male_over_64
# robbery_male_under_10
# robbery_tot_10_12
# robbery_tot_13_14
# robbery_tot_15
# robbery_tot_16
# robbery_tot_17
# robbery_tot_18
# robbery_tot_19
# robbery_tot_20
# robbery_tot_21
# robbery_tot_22
# robbery_tot_23
# robbery_tot_24
# robbery_tot_25_29
# robbery_tot_30_34
# robbery_tot_35_39
# robbery_tot_40_44
# robbery_tot_45_49
# robbery_tot_50_54
# robbery_tot_55_59
# robbery_tot_60_64
# robbery_tot_adult
# robbery_tot_arrests
# robbery_tot_female
# robbery_tot_female_adult
# robbery_tot_female_juv
# robbery_tot_juv
# robbery_tot_male
# robbery_tot_male_adult
# robbery_tot_male_juv
# robbery_tot_over_64
# robbery_tot_under_10
# theft_female_10_12
# theft_female_13_14
# theft_female_15
# theft_female_16
# theft_female_17
# theft_female_18
# theft_female_19
# theft_female_20
# theft_female_21
# theft_female_22
# theft_female_23
# theft_female_24
# theft_female_25_29
# theft_female_30_34
# theft_female_35_39
# theft_female_40_44
# theft_female_45_49
# theft_female_50_54
# theft_female_55_59
# theft_female_60_64
# theft_female_over_64
# theft_female_under_10
# theft_male_10_12
# theft_male_13_14
# theft_male_15
# theft_male_16
# theft_male_17
# theft_male_18
# theft_male_19
# theft_male_20
# theft_male_21
# theft_male_22
# theft_male_23
# theft_male_24
# theft_male_25_29
# theft_male_30_34
# theft_male_35_39
# theft_male_40_44
# theft_male_45_49
# theft_male_50_54
# theft_male_55_59
# theft_male_60_64
# theft_male_over_64
# theft_male_under_10
# theft_tot_10_12
# theft_tot_13_14
# theft_tot_15
# theft_tot_16
# theft_tot_17
# theft_tot_18
# theft_tot_19
# theft_tot_20
# theft_tot_21
# theft_tot_22
# theft_tot_23
# theft_tot_24
# theft_tot_25_29
# theft_tot_30_34
# theft_tot_35_39
# theft_tot_40_44
# theft_tot_45_49
# theft_tot_50_54
# theft_tot_55_59
# theft_tot_60_64
# theft_tot_adult
# theft_tot_arrests
# theft_tot_female
# theft_tot_female_adult
# theft_tot_female_juv
# theft_tot_juv
# theft_tot_male
# theft_tot_male_adult
# theft_tot_male_juv
# theft_tot_over_64
# theft_tot_under_10
# juv_handled_within_department
# juv_referred_to_juv_court
# juv_referred_to_welfare
# juv_referred_to_police
# juv_referred_to_crim_court
# total_arrests
# log_total_arrests
# post_overall
